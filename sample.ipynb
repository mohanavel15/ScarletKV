# %%
import redis

# %%
r = redis.Redis(host='10.150.3.6', port=6379, decode_responses=True)

# %%
r.set('hello', 'world')

# %%
r.get('hello')

# %%
r.delete('hello')

# %%
r.set('counter', 4)

# %%
r.incr('counter')

# %%
r.incr('counter', 5)
r.incr('counter', 4)
r.incr('counter', 3)
r.incr('counter', 2)
r.incr('counter', 1)

# %%
r.get('counter')

# %%
r.decr('counter', 5)
r.decr('counter', 4)
r.decr('counter', 3)
r.decr('counter', 2)
r.decr('counter', 1)

# %%
r.get('counter')

# %%
r.exists('counter')

# %%
r.exists('counter', 'hello')
